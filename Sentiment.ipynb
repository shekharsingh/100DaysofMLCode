# %% [markdown]
# <a href="https://colab.research.google.com/github/shekharsingh/100DaysofMLCode/blob/master/Sentiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline
sentiment=pipeline('sentiment-analysis',model='tabularisai/multilingual-sentiment-analysis')
# Out:
# config.json:   0%|          | 0.00/851 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/541M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Device set to use cpu

# %%
sentiment('customer service was fine')
# Out:
# [{'label': 'Neutral', 'score': 0.7933783531188965}]
